# %%
from pathlib import Path

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Breakout
# 1. `withscore-control`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskip-v4_1"
# 2. `noscore-control`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskipNoScore-v4_1"
# 3. `withscore-rm`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskip-v4_2"
# 4. `noscore-rm`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskipNoScore-v4_2"
#
# ### Seaquest
# 1. `withscore-control`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskip-v4_1"
# 2. `noscore-control`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskipNoScore-v4_1"
# 3. `withscore-rm`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskip-v4_2"
# 4. `noscore-rm`: "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskipNoScore-v4_2"

# %%
paths = {
    'breakout': {
        'withscore-control': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskip-v4_1/evaluations.npz",
        'noscore-control': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskipNoScore-v4_1/evaluations.npz",
        'withscore-rm': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskip-v4_2/evaluations.npz",
        'noscore-rm': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/BreakoutNoFrameskipNoScore-v4_2/evaluations.npz"
    },
    'seaquest': {
        'withscore-control': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskip-v4_1/evaluations.npz",
        'noscore-control': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskipNoScore-v4_1/evaluations.npz",
        'withscore-rm': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskip-v4_2/evaluations.npz",
        'noscore-rm': "/home/eric/interpreting-rewards/scripts/output/regressed_exps/ppo/SeaquestNoFrameskipNoScore-v4_2/evaluations.npz"
    }
}

# %%
plt.figure(figsize=(6.5, 4))

plt.subplot(2, 2, 1)
with np.load(paths['breakout']['withscore-control']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="blue", label="With Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="blue")

with np.load(paths['breakout']['noscore-control']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="orange", label="Without Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="orange")
plt.ylim(-5, 40)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel("Timesteps", fontsize=8)
plt.ylabel("Episode Return", fontsize=8)
plt.legend(loc='upper left', prop={'size': 6})
plt.title("Breakout w/ Ground Truth Reward", fontsize=10)


plt.subplot(2, 2, 3)
with np.load(paths['breakout']['withscore-rm']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="blue", label="With Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="blue")

with np.load(paths['breakout']['noscore-rm']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="orange", label="Without Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="orange")
plt.ylim(-5, 40)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel("Timesteps", fontsize=8)
plt.ylabel("Episode Return", fontsize=8)
plt.legend(loc='upper left', prop={'size': 6})
plt.title("Breakout w/ Regressed Reward", fontsize=10)


plt.subplot(2, 2, 2)
with np.load(paths['seaquest']['withscore-control']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="blue", label="With Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="blue")

with np.load(paths['seaquest']['noscore-control']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="orange", label="Without Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="orange")
plt.ylim(-5, 40)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel("Timesteps", fontsize=8)
plt.ylabel("Episode Return", fontsize=8)
plt.legend(loc='upper left', prop={'size': 6})
plt.title("Seaquest w/ Ground Truth Reward", fontsize=10)


plt.subplot(2, 2, 4)
with np.load(paths['seaquest']['withscore-rm']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="blue", label="With Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="blue")

with np.load(paths['seaquest']['noscore-rm']) as data:
    timesteps = data['timesteps']
    results = data['results']
means = np.mean(results, axis=1).flatten()
stds = np.std(results, axis=1).flatten()
plt.plot(timesteps, means, color="orange", label="Without Score")
plt.fill_between(timesteps, means-stds, means+stds, alpha=0.1, color="orange")
plt.ylim(-5, 40)
plt.xticks(fontsize=8)
plt.yticks(fontsize=8)
plt.xlabel("Timesteps", fontsize=8)
plt.ylabel("Episode Return", fontsize=8)
plt.legend(loc='upper left', prop={'size': 6})
plt.title("Seaquest w/ Regressed Reward", fontsize=10)

plt.subplots_adjust(hspace=0.5, wspace=0.25)
plt.savefig("atariocclusion/ppo-training-curves.pdf", dpi=300, bbox_inches='tight')

# %%
with np.load(paths['breakout']['withscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 13.5

# %%
with np.load(paths['breakout']['withscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 3.8

# %%
with np.load(paths['breakout']['noscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 13.2

# %%
with np.load(paths['breakout']['noscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 10.4

# %%
with np.load(paths['breakout']['withscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 13.5

# %%
with np.load(paths['breakout']['withscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 3.8

# %%
with np.load(paths['breakout']['noscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 13.2

# %%
with np.load(paths['breakout']['noscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 10.4

# %%
with np.load(paths['seaquest']['withscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 22.6

# %%
with np.load(paths['seaquest']['withscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 8.7

# %%
with np.load(paths['seaquest']['noscore-control']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 11.3

# %%
with np.load(paths['seaquest']['noscore-rm']) as data:
    results = data['results']
results[-1].mean()
# Out:
# 6.6

# %% [markdown]
# # Let's make videos of reward vs. time as an agent plays Breakout and Atari

# %%
import os
import sys
import importlib
from pathlib import Path
from itertools import product
import h5py

import gym
import numpy as np
import matplotlib
import matplotlib.cm
import matplotlib.pyplot as plt
import scipy.ndimage
import skimage.transform
import torch as th
import torch.nn as nn

from tqdm.auto import tqdm

from stable_baselines3.common.utils import set_random_seed
from stable_baselines3.common.atari_wrappers import AtariWrapper
from stable_baselines3.common.vec_env import VecEnvWrapper, VecEnv, DummyVecEnv, VecFrameStack
from stable_baselines3.common.vec_env import VecTransposeImage

sys.path.insert(1, "../rl-baselines3-zoo")
import utils.import_envs  # noqa: F401 pylint: disable=unused-import
from utils.utils import StoreDict
from utils import ALGOS, create_test_env, get_latest_run_id, get_saved_hyperparams

import interp

# %%
matplotlib.use("Agg")
import matplotlib.animation as manimation

# %%
########### Set Device ############
# device = th.device('cuda' if th.cuda.is_available() else 'cpu')
device = 'cpu'
dtype = th.float32
th.set_default_dtype(dtype)
print("Using device: {}".format(device))
# Out:
# Using device: cpu

# %% [markdown]
# ## Define reward model

# %%
class RewardModel(nn.Module):
    """A reward model using an A2C feature extractor"""
    def __init__(self, env, device):
        super(RewardModel, self).__init__()
        self.ac_model = ALGOS['a2c']('CnnPolicy', env).policy
        self.reward_net = nn.Linear(512, 1).to(device)
        self.device = device
    
    def forward(self, obs):
        obs_transposed = VecTransposeImage.transpose_image(obs)
        latent, _, _= self.ac_model._get_latent(th.tensor(obs_transposed).to(self.device))
        return self.reward_net(latent)
    
    def forward_tensor(self, obs):
        """obs is a tensor which has already been transposed correctly."""
        latent, _, _= self.ac_model._get_latent(obs.to(self.device))
        return self.reward_net(latent)
    
    def freeze_extractor(self):
        for p in self.ac_model.policy.features_extractor.parameters():
            p.requires_grad = False

# %% [markdown]
# ## Define functions for computing saliency

# %%
def get_mask(center, size, r):
    y,x = np.ogrid[-center[0]:size[0]-center[0], -center[1]:size[1]-center[1]]
    keep = x*x + y*y <= 1
    mask = np.zeros(size) ; mask[keep] = 1 # select a circle of pixels
    mask = scipy.ndimage.gaussian_filter(mask, sigma=r) # blur the circle of pixels. this is a 2D Gaussian for r=r^2=1
    return mask/mask.max()

def occlude(img, mask):
    assert img.shape[1:] == (84, 84, 4)
    img = np.copy(img)
    for k in range(4):
        I = img[0, :, :, k]
        img[0, :, :, k] = I*(1-mask) + scipy.ndimage.gaussian_filter(I, sigma=3)*mask
    return img

def compute_saliency_map(reward_model, obs, stride=5, radius=5):
    baseline = reward_model(obs).detach().cpu().numpy()
    scores = np.zeros((84 // stride + 1, 84 // stride + 1))
    for i in range(0, 84, stride):
        for j in range(0, 84, stride):
            mask = get_mask(center=(i, j), size=(84, 84), r=radius)
            obs_perturbed = occlude(obs, mask)
            perturbed_reward = reward_model(obs_perturbed).detach().cpu().numpy()
            scores[i // stride, j // stride] = 0.5 * np.abs(perturbed_reward - baseline) ** 2
    pmax = scores.max()
    scores = skimage.transform.resize(scores, output_shape=(210, 160))
    scores = scores.astype(np.float32)
#     return pmax * scores / scores.max()
    return scores / scores.max()

def add_saliency_to_frame(frame, saliency, channel=1):
#     def saliency_on_atari_frame(saliency, atari, fudge_factor, channel=2, sigma=0):
    # sometimes saliency maps are a bit clearer if you blur them
    # slightly...sigma adjusts the radius of that blur
    pmax = saliency.max()
    I = frame.astype('uint16')
    I[:, :, channel] += (frame.max() * saliency).astype('uint16')
    I = I.clip(1,255).astype('uint8')
    return I

# %% [markdown]
# # BreakoutNoFrameskip-v4
# ### Environment and Agent: BreakoutNoFrameskip-v4
# ### Reward Model: BreakoutNoFrameskip-v4

# %%
env_id = "BreakoutNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/BreakoutNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/breakout_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %% [markdown]
# ### Environment and Agent: BreakoutNoFrameskipNoScore-v4
# ### Reward Model: BreakoutNoFrameskip-v4

# %%
env_id = "BreakoutNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/BreakoutNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/breakout_reward_noscore_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %% [markdown]
# ### Environment and Agent: SeaquestNoFrameskip-v4
# ### Reward Model: SeaquestNoFrameskip-v4

# %%
env_id = "SeaquestNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/seaquest_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %% [markdown]
# ### Environment and Agent: SeaquestNoFrameskip-v4
# ### Reward Model: SeaquestNoFrameskip-v4

# %%
env_id = "SeaquestNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/seaquest_reward_noscore_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %% [markdown]
# # Let's load up a regularized reward model now

# %%
env_id = "BreakoutNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/BreakoutNoFrameskip-v4-reward_model_sparse.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/breakout_sparse_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "SeaquestNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model_sparse.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/seaquest_sparse_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "SeaquestNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model_sparse.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/seaquest_sparse_reward_noscore_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "SeaquestNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/seaquest_reward_noscore_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        sal = compute_saliency_map(rm, obs)
        screenshot = env.render(mode='rgb_array')
        image = add_saliency_to_frame(screenshot, sal)

        imshow.set_data(image)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:38: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "BreakoutNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/BreakoutNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
# env = gym.make('BreakoutNoFrameskipNoScore-v4')
# env = AtariWrapper(env, frame_skip=1)
# env = DummyVecEnv([lambda: env])
# env = VecFrameStack(env, n_stack=4)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')

# %%
plt.imshow(image)

# %%
sal = compute_saliency_map(rm, obs)
screenshot = env.render(mode='rgb_array')
image = add_saliency_to_frame(screenshot, sal)

# %%
plt.imshow(image)

# %%
matplotlib.use("Agg")
import matplotlib.animation as manimation

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "presentation/breakout_noscore_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        screenshot = env.render(mode='rgb_array')
        imshow.set_data(screenshot)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "BreakoutNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/BreakoutNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Breakout Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "../videos/breakout/breakout_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        screenshot = env.render(mode='rgb_array')
        imshow.set_data(screenshot)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "SeaquestNoFrameskipNoScore-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')

# %%
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Seaquest Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "../videos/seaquest/seaquest_noscore_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        screenshot = env.render(mode='rgb_array')
        imshow.set_data(screenshot)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.

# %%
env_id = "SeaquestNoFrameskip-v4"
folder = "/home/eric/interpreting-rewards/scripts/output/regressed_exps/"
algo = "ppo"
n_timesteps = 10000
num_threads = -1
n_envs = 1
exp_id = 1
verbose = 1
no_render = False
deterministic = False
load_best = True
load_checkpoint = None
norm_reward = False
seed = 0
reward_log = ''
env_kwargs = None

# %%
# Sanity checks
if exp_id > 0:
    log_path = os.path.join(folder, algo, '{}_{}'.format(env_id, exp_id))
else:
    log_path = os.path.join(folder, algo)
    
found = False
for ext in ['zip']:
    model_path = os.path.join(log_path, f'{env_id}.{ext}')
    found = os.path.isfile(model_path)
    if found:
        break

if load_best:
    model_path = os.path.join(log_path, "best_model.zip")
    found = os.path.isfile(model_path)

if load_checkpoint is not None:
    model_path = os.path.join(log_path, f"rl_model_{load_checkpoint}_steps.zip")
    found = os.path.isfile(model_path)

if not found:
    raise ValueError(f"No model found for {algo} on {env_id}, path: {model_path}")

if algo in ['dqn', 'ddpg', 'sac', 'td3']:
    n_envs = 1

set_random_seed(seed)

if num_threads > 0:
    if verbose > 1:
        print(f"Setting torch.num_threads to {num_threads}")
    th.set_num_threads(num_threads)

is_atari = 'NoFrameskip' in env_id

stats_path = os.path.join(log_path, env_id)
hyperparams, stats_path = get_saved_hyperparams(stats_path, norm_reward=norm_reward, test_mode=True)
env_kwargs = {} if env_kwargs is None else env_kwargs

log_dir = reward_log if reward_log != '' else None

env = create_test_env(env_id, n_envs=n_envs,
                      stats_path=stats_path, seed=seed, log_dir=log_dir,
                      should_render=not no_render,
                      hyperparams=hyperparams,
                      env_kwargs=env_kwargs)

model = ALGOS[algo].load(model_path, env=env, device=device)

obs = env.reset()
# Out:
# Stacking 4 frames

# %%
rm = RewardModel(env, device)
rm.load_state_dict(th.load(f"../reward-models/SeaquestNoFrameskip-v4-reward_model.pt"))
rm = rm.to(device)

# %%
obs = env.reset()
image = env.render(mode='rgb_array')

# %%
plt.imshow(image)

# %%
radius = 5
stride = 4

TIMESTEPS = 400

FFMpegWriter = manimation.writers['ffmpeg']
metadata = dict(title=f"Seaquest Reward vs. time", artist='Matplotlib',
                comment='Movie support!')
writer = FFMpegWriter(fps=20, metadata=metadata)

fig, (ax, ax2) = plt.subplots(1, 2, gridspec_kw={'width_ratios': [1, 1]}, figsize=(10, 5))
# ax.set_title(f"mnist: {top_str}", fontsize=15)
# ax.set_ylabel('Sensitivity / Degeneracy', fontsize=15)
# ax.set_xlabel("← More Degenerate — More Sensitive →", fontsize=15)
# ax.set_xlim([-1, 17])
# ax.set_ylim([0, 22000])
ax2.set_xlabel("Time", fontsize=15)
ax2.set_title("reward", fontsize=15)

obs = env.reset()
imshow = ax.imshow(env.get_images()[0])
timeseries = ax2.plot([], [], c='black')[0]
rewards = []
with writer.saving(fig, "../videos/seaquest/seaquest_reward_vs_time.mp4", dpi=200):
    for i in tqdm(range(TIMESTEPS)):
        action, _states = model.predict(obs, deterministic=False)
        obs, reward, done, info = env.step(action)
        if done:
            obs = env.reset()
        screenshot = env.render(mode='rgb_array')
        imshow.set_data(screenshot)
        
        rewards.append(rm(obs).item())
        
        ax2.set_xlim(list(range(i+1))[-40:][0], list(range(i+1))[-40:][-1])
#         ax2.set_yscale('log')
        ax2.set_ylim(0.0001, 1.1)
        timeseries.set_data(list(range(i+1))[-40:], rewards[-40:])
        writer.grab_frame()
#         plt.subplots_adjust(wspace=0.2)
# Out:
# ...
# /home/eric/miniconda3/envs/interp/lib/python3.7/site-packages/ipykernel_launcher.py:35: UserWarning: Attempting to set identical left == right == 0 results in singular transformations; automatically expanding.
